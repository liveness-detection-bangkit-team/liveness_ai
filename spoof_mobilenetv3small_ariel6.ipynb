# %% [markdown]
# <a href="https://colab.research.google.com/github/liveness-detection-bangkit-team/liveness_ai/blob/main/spoof_mobilenetv3small_ariel6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install ai-edge-litert
#!pip install tflite-support-nightly
# Out:
# Collecting tflite-support-nightly
#   Downloading tflite_support_nightly-0.4.4.dev20230716-cp310-cp310-manylinux2014_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tflite-support-nightly) (1.4.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from tflite-support-nightly) (1.26.4)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tflite-support-nightly) (24.3.25)
# Collecting protobuf<4,>=3.18.0 (from tflite-support-nightly)
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (679 bytes)
# Collecting sounddevice>=0.4.4 (from tflite-support-nightly)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting pybind11>=2.6.0 (from tflite-support-nightly)
#   Downloading pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->tflite-support-nightly) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->tflite-support-nightly) (2.22)
# Downloading tflite_support_nightly-0.4.4.dev20230716-cp310-cp310-manylinux2014_x86_64.whl (60.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 MB 11.3 MB/s eta 0:00:00
# Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.8 MB/s eta 0:00:00
# Downloading pybind11-2.13.6-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 18.7 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Installing collected packages: pybind11, protobuf, sounddevice, tflite-support-nightly
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed protobuf-3.20.3 pybind11-2.13.6 sounddevice-0.5.1 tflite-support-nightly-0.4.4.dev20230716

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import cv2
import numpy as np
import matplotlib.image as mpimg
from keras.preprocessing.image import load_img, img_to_array
from google.colab.patches import cv2_imshow
import seaborn as sns
import os
import pandas as pd
import itertools

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
#from ai_edge_litert.interpreter import Interpreter
#from tflite_support.metadata_writers import image_classifier
#from tflite_support.metadata_writers import writer_utils
print(tf.__version__)
# Out:
# 2.17.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path ke direktori dataset
train_dir = '/content/drive/MyDrive/datasets/datasets/train_spoof'
test_dir = '/content/drive/MyDrive/datasets/datasets/test_spoof'
MODEL_PATH = "/content/drive/MyDrive/Model_ariel"

# %%
seed_init = 42
IMAGE_SIZE = (224, 224)
train_dataset = tf.keras.utils.image_dataset_from_directory(
    seed = seed_init,
    directory= train_dir,
    image_size= IMAGE_SIZE,
    shuffle = True,
    #batch_size = None,
    subset = 'training',
    validation_split = 0.2,
    label_mode= 'binary',
)


validation_dataset = tf.keras.utils.image_dataset_from_directory(
    seed = seed_init,
    directory= train_dir,
    image_size= IMAGE_SIZE,
    shuffle = True,
    #batch_size = None,
    subset= 'validation',
    validation_split = 0.2,
		label_mode= 'binary',
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    seed = seed_init,
    directory= test_dir,
    #batch_size= None,
    image_size= IMAGE_SIZE,
    label_mode= 'binary',
)
# Out:
# Found 5958 files belonging to 2 classes.
# Using 4767 files for training.
# Found 5958 files belonging to 2 classes.
# Using 1191 files for validation.
# Found 100 files belonging to 2 classes.

# %%
train_class_names = train_dataset.class_names
print("Class names:", train_class_names)
for images, labels in train_dataset.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        label_index = tf.argmax(labels[i]).numpy()
        plt.title(train_class_names[label_index])
        plt.axis("off")
    plt.show()
# Out:
# Class names: ['fake', 'real']

# %%
validation_class_names = validation_dataset.class_names  # Get class names
print("Class names:", validation_class_names)

for images, labels in validation_dataset.take(1):  # Take one batch
    plt.figure(figsize=(10, 10))
    for i in range(9):  # Show first 9 images in the batch
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))  # Convert tensor to uint8 image
        label_index = tf.argmax(labels[i]).numpy()  # Get the index of the highest value in the one-hot array
        plt.title(validation_class_names[label_index])  # Get class name using the index
        plt.axis("off")
    plt.show()
# Out:
# Class names: ['fake', 'real']

# %%
test_class_names = test_dataset.class_names  # Get class names
print("Class names:", test_class_names)

for images, labels in test_dataset.take(1):  # Take one batch
    plt.figure(figsize=(10, 10))
    for i in range(9):  # Show first 9 images in the batch
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))  # Convert tensor to uint8 image
        label_index = tf.argmax(labels[i]).numpy()  # Get the index of the highest value in the one-hot array
        plt.title(test_class_names[label_index])  # Get class name using the index
        plt.axis("off")
    plt.show()
# Out:
# Class names: ['fake', 'real']

# %%
subdirectories = [os.path.join(train_dir, d) for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))]

counts = [len(os.listdir(directory)) for directory in subdirectories]

labels = [os.path.basename(directory) for directory in subdirectories]

print(counts)
plt.bar(labels, counts)
plt.xticks(rotation=90)
plt.ylabel("Number of Images")
plt.xlabel("Subdirectories")
plt.title("Image Distribution in Subdirectories")
plt.tight_layout()
plt.show()
# Out:
# [2979, 2979]

# %%
subdirectories = [os.path.join(test_dir, d) for d in os.listdir(test_dir) if os.path.isdir(os.path.join(test_dir, d))]


counts = [len(os.listdir(directory)) for directory in subdirectories]

labels = [os.path.basename(directory) for directory in subdirectories]

print(counts)

plt.bar(labels, counts)
plt.xticks(rotation=90)
plt.ylabel("Number of Images")
plt.xlabel("Subdirectories")
plt.title("Image Distribution in Subdirectories")
plt.tight_layout()
plt.show()
# Out:
# [50, 50]

# %%
# data normalization
"""
data_preprocessing = tf.keras.Sequential([
    tf.keras.layers.Resizing(224, 224),
    tf.keras.layers.Rescaling(scale=1 / 127.5, offset=-1),
])
"""

# %%
# data augmentation
"""
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomBrightness([-0.8,0]),
  tf.keras.layers.RandomContrast(0.2)
])
"""
# Out:
# '\ndata_augmentation = tf.keras.Sequential([\n  tf.keras.layers.RandomBrightness([-0.8,0]),\n  tf.keras.layers.RandomContrast(0.2)\n])\n'

# %%
# augmenting
# train_dataset = train_dataset.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
# optimmize
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
# normalizing on dataset
"""
train_dataset = train_dataset.map(lambda x, y: (tf.keras.applications.mobilenet_v3.preprocess_input(x), y))
validation_dataset = validation_dataset.map(lambda x, y: (tf.keras.applications.mobilenet_v3.preprocess_input(x), y))
test_dataset = test_dataset.map(lambda x, y: (tf.keras.applications.mobilenet_v3.preprocess_input(x), y))
"""

# %%
# optimize
"""
batch_size = 32

train_dataset = train_dataset.cache().batch(batch_size).prefetch(buffer_size=10)
validation_dataset = validation_dataset.cache().batch(batch_size).prefetch(buffer_size=10)
test_dataset = test_dataset.cache().batch(batch_size).prefetch(buffer_size=10)
"""

# %%
IMAGE_SHAPE = (224, 224, 3)
base_model = MobileNetV3Small(weights='imagenet', include_top=False, input_shape=IMAGE_SHAPE)
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "MobileNetV3Small"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling (Rescaling)     │ (None, 224, 224, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv (Conv2D)             │ (None, 112, 112, 16)   │            432 │ rescaling[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_bn                   │ (None, 112, 112, 16)   │             64 │ conv[0][0]             │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 112, 112, 16)   │              0 │ conv_bn[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 113, 113, 16)   │              0 │ activation[0][0]       │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 56, 56, 16)     │            144 │ expanded_conv_depthwi… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 56, 56, 16)     │             64 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 56, 56, 16)     │              0 │ expanded_conv_depthwi… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_squeeze_ex… │ (None, 1, 1, 16)       │              0 │ re_lu[0][0]            │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_squeeze_ex… │ (None, 1, 1, 8)        │            136 │ expanded_conv_squeeze… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_squeeze_ex… │ (None, 1, 1, 8)        │              0 │ expanded_conv_squeeze… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_squeeze_ex… │ (None, 1, 1, 16)       │            144 │ expanded_conv_squeeze… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 1, 1, 16)       │              0 │ expanded_conv_squeeze… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 1, 1, 16)       │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 1, 1, 16)       │              0 │ re_lu_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_squeeze_ex… │ (None, 56, 56, 16)     │              0 │ re_lu[0][0],           │
# │ (Multiply)                │                        │                │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 56, 56, 16)     │            256 │ expanded_conv_squeeze… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_bn  │ (None, 56, 56, 16)     │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_1
│
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_1 (Conv2D)           │ (None, 7, 7, 576)      │         55,296 │ expanded_conv_10_add[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_1_bn                 │ (None, 7, 7, 576)      │          2,304 │ conv_1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 7, 7, 576)      │              0 │ conv_1_bn[0][0]        │
# │ (Activation)              │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 939,120 (3.58 MB)
#  Trainable params: 927,008 (3.54 MB)
#  Non-trainable params: 12,112 (47.31 KB)

# %%
#base_model.trainable = False
inputs = base_model.input
# We make sure that the base_model is running in inference mode here,
# by passing `training=False`. This is important for fine-tuning, as you will
# learn in a few paragraphs.
# x = data_augmentation(inputs)
#x = tf.keras.applications.mobilenet_v3.preprocess_input(inputs)
x = base_model(inputs, training=False)
# Convert features of shape `base_model.output_shape[1:]` to vectors
x = tf.keras.layers.GlobalAveragePooling2D()(x)
# A Dense classifier with a single unit (binary classification)
x = tf.keras.layers.Dense(512, activation='relu')(x)
x = tf.keras.layers.Dropout(0.5)(x)
outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
model = tf.keras.Model(inputs, outputs)
print("trainable: ", base_model.trainable)
# Out:
# trainable:  True

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(
                  learning_rate=0.001,
                  beta_1 = 0.9,
                  beta_2 = 0.999,
                  weight_decay = 0.0
                ),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ MobileNetV3Small (Functional)        │ (None, 7, 7, 576)           │         939,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 576)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         295,424 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,235,057 (4.71 MB)
#  Trainable params: 1,222,945 (4.67 MB)
#  Non-trainable params: 12,112 (47.31 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
ReduceOnPlateau = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=2,
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=5,
    restore_best_weights=True
    )

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    os.path.join(MODEL_PATH, "spoof_mobilenetv3s_finetuned_checkpoint_ariel8.keras"),
    monitor="val_accuracy",
    verbose=1,
    save_best_only=True,
    save_weights_only=False,
    mode="max",
    save_freq="epoch",
    )

history = model.fit(train_dataset, epochs=25, validation_data=validation_dataset, callbacks=[ReduceOnPlateau, early_stopping, checkpoint])

# Save model
model.save(os.path.join(MODEL_PATH, 'spoof_mobilenetv3s_finetuned_ariel8.keras'))

# Mengonversi model ke TFLite
loaded_model = tf.keras.models.load_model(os.path.join(MODEL_PATH, 'spoof_mobilenetv3s_finetuned_ariel8.keras'))
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Menyimpan model TFLite ke file
tflite_model_path = os.path.join(MODEL_PATH, 'spoof_mobilenetv3s_finetuned_ariel8.tflite')
with open(tflite_model_path, 'wb') as f:
    f.write(tflite_model)
# Out:
# Epoch 1/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8765 - loss: 0.2618 - precision: 0.8728 - recall: 0.8748
# Epoch 1: val_accuracy improved from -inf to 0.66919, saving model to /content/drive/MyDrive/Model_ariel/spoof_mobilenetv3s_finetuned_checkpoint_ariel8.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 847s 5s/step - accuracy: 0.8769 - loss: 0.2612 - precision: 0.8732 - recall: 0.8752 - val_accuracy: 0.6692 - val_loss: 2.5519 - val_precision: 0.9664 - val_recall: 0.3734 - learning_rate: 0.0010
# Epoch 2/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9846 - loss: 0.0437 - precision: 0.9826 - recall: 0.9859
# Epoch 2: val_accuracy did not improve from 0.66919
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 97s 399ms/step - accuracy: 0.9846 - loss: 0.0437 - precision: 0.9826 - recall: 0.9859 - val_accuracy: 0.6608 - val_loss: 6.3799 - val_precision: 0.9953 - val_recall: 0.3458 - learning_rate: 0.0010
# Epoch 3/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9902 - loss: 0.0258 - precision: 0.9868 - recall: 0.9933
# Epoch 3: val_accuracy improved from 0.66919 to 0.69102, saving model to /content/drive/MyDrive/Model_ariel/spoof_mobilenetv3s_finetuned_checkpoint_ariel8.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 61s 407ms/step - accuracy: 0.9902 - loss: 0.0258 - precision: 0.9868 - recall: 0.9933 - val_accuracy: 0.6910 - val_loss: 5.1821 - val_precision: 0.9960 - val_recall: 0.4042 - learning_rate: 0.0010
# Epoch 4/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.9930 - loss: 0.0185 - precision: 0.9903 - recall: 0.9956
# Epoch 4: val_accuracy improved from 0.69102 to 0.78673, saving model to /content/drive/MyDrive/Model_ariel/spoof_mobilenetv3s_finetuned_checkpoint_ariel8.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 85s 426ms/step - accuracy: 0.9930 - loss: 0.0185 - precision: 0.9903 - recall: 0.9956 - val_accuracy: 0.7867 - val_loss: 1.8642 - val_precision: 0.9973 - val_recall: 0.5893 - learning_rate: 1.0000e-04
# Epoch 5/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9982 - loss: 0.0075 - precision: 0.9981 - recall: 0.9983
# Epoch 5: val_accuracy improved from 0.78673 to 0.85726, saving model to /content/drive/MyDrive/Model_ariel/spoof_mobilenetv3s_finetuned_checkpoint_ariel8.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 77s 395ms/step - accuracy: 0.9982 - loss: 0.0075 - precision: 0.9981 - recall: 0.9983 - val_accuracy: 0.8573 - val_loss: 0.8634 - val_precision: 0.9978 - val_recall: 0.7256 - learning_rate: 1.0000e-04
# Epoch 6/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9989 - loss: 0.0035 - precision: 0.9990 - recall: 0.9988
# Epoch 6: val_accuracy improved from 0.85726 to 0.93115, saving model to /content/drive/MyDrive/Model_ariel/spoof_mobilenetv3s_finetuned_checkpoint_ariel8.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 59s 399ms/step - accuracy: 0.9989 - loss: 0.0035 - precision: 0.9990 - recall: 0.9988 - val_accuracy: 0.9312 - val_loss: 0.2960 - val_precision: 0.9981 - val_recall: 0.8685 - learning_rate: 1.0000e-04
# Epoch 7/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9998 - loss: 0.0024 - precision: 0.9999 - recall: 0.9997
# Epoch 7: val_accuracy improved from 0.93115 to 0.96306, saving model to /content/drive/MyDrive/Model_ariel/spoof_mobilenetv3s_finetuned_checkpoint_ariel8.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 59s 399ms/step - accuracy: 0.9998 - loss: 0.0024 - precision: 0.9999 - recall: 0.9997 - val_accuracy: 0.9631 - val_loss: 0.1243 - val_precision: 0.9965 - val_recall: 0.9318 - learning_rate: 1.0000e-04
# Epoch 8/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9975 - loss: 0.0062 - precision: 0.9959 - recall: 0.9991
# Epoch 8: val_accuracy improved from 0.96306 to 0.98153, saving model to /content/drive/MyDrive/Model_ariel/spoof_mobilenetv3s_finetuned_checkpoint_ariel8.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 84s 412ms/step - accuracy: 0.9975 - loss: 0.0061 - precision: 0.9959 - recall: 0.9991 - val_accuracy: 0.9815 - val_loss: 0.0477 - val_precision: 0.9983 - val_recall: 0.9659 - learning_rate: 1.0000e-04
# Epoch 9/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 1.0000 - loss: 0.0013 - precision: 1.0000 - recall: 1.0000
# Epoch 9: val_accuracy improved from 0.98153 to 0.99328, saving model to /content/drive/MyDrive/Model_ariel/spoof_mobilenetv3s_finetuned_checkpoint_ariel8.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 80s 397ms/step - accuracy: 1.0000 - loss: 0.0013 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9933 - val_loss: 0.0240 - val_precision: 0.9984 - val_recall: 0.9886 - learning_rate: 1.0000e-04
# Epoch 10/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 1.0000 - loss: 8.6704e-04 - precision: 1.0000 - recall: 1.0000
# Epoch 10: val_accuracy improved from 0.99328 to 0.99664, saving model to /content/drive/MyDrive/Model_ariel/spoof_mobilenetv3s_finetuned_checkpoint_ariel8.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 91s 460ms/step - accuracy: 1.0000 - loss: 8.6584e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9966 - val_loss: 0.0115 - val_precision: 0.9984 - val_recall: 0.9951 - learning_rate: 1.0000e-04
# Epoch 11/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9997 - loss: 0.0016 - precision: 1.0000 - recall: 0.9993
# Epoch 11: val_accuracy did not improve from 0.99664
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 81s 455ms/step - accuracy: 0.9997 - loss: 0.0016 - precision: 1.0000 - recall: 0.9993 - val_accuracy: 0.9958 - val_loss: 0.0143 - val_precision: 0.9951 - val_recall: 0.9968 - learning_rate: 1.0000e-04
# Epoch 12/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 1.0000 - loss: 8.9846e-04 - precision: 1.0000 - recall: 1.0000
# Epoch 12: val_accuracy did not improve from 0.99664
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 84s 470ms/step - accuracy: 1.0000 - loss: 8.9703e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9958 - val_loss: 0.0126 - val_precision: 0.9951 - val_recall: 0.9968 - learning_rate: 1.0000e-04
# Epoch 13/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9995 - loss: 0.0015 - precision: 0.9990 - recall: 1.0000
# Epoch 13: val_accuracy did not improve from 0.99664
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 80s 458ms/step - accuracy: 0.9995 - loss: 0.0015 - precision: 0.9990 - recall: 1.0000 - val_accuracy: 0.9966 - val_loss: 0.0111 - val_precision: 0.9951 - val_recall: 0.9984 - learning_rate: 1.0000e-05
# Epoch 14/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 1.0000 - loss: 3.2944e-04 - precision: 1.0000 - recall: 1.0000
# Epoch 14: val_accuracy did not improve from 0.99664
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 72s 394ms/step - accuracy: 1.0000 - loss: 3.3022e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9966 - val_loss: 0.0108 - val_precision: 0.9951 - val_recall: 0.9984 - learning_rate: 1.0000e-05
# Epoch 15/25
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 1.0000 - loss: 4.7090e-04 - precision: 1.0000 - recall: 1.0000
# Epoch 15: val_accuracy did not improve from 0.99664
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 58s 393ms/step - accuracy: 1.0000 - loss: 4.7026e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9966 - val_loss: 0.0108 - val_precision: 0.9951 - val_recall: 0.9984 - learning_rate: 1.0000e-05
# Saved artifact at '/tmp/tmphhq7flfl'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   140316348525808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316348530384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140317655169712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140318497941008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140321218163840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347992720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347995008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347990608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316348002928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316348000464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347999232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316646154032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316646146112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316348102640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316348101584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347756640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347758928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316348098064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347758752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316348095424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316348672208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316348670448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316348662880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316348673440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316348099472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346798976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346800032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346796160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346798800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346806192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346805136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346807600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346803728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346806368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346809360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346862224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346860288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346862576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346862400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346869440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346868384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346870848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346866976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346869616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346866624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346926704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346925296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346874896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346926880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346865216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346932864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346935328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346931456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346934096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346931104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347009152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347007216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316346940960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347009328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347017952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347009504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347022176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347019008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347016368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347126656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347127712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347123840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347126480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347132640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347131584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347134048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347130176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347132816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347137216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347190080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347188144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347190608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347190256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347198880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347187264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347203104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347200112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347197296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347258432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347259488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347255616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347258256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347265824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347264768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347267232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347263360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347266000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347253856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347405184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347406240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347402368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347405008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347413984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347402016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347415040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347415744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347412400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347457152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347458208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347454336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347456976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347464544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347463488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347459968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347462080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347464720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347452576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347571136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347572192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347568320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347570960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347579936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347576768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347575536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347667152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347579760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347672256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347673312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347669440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347672080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347678240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347669792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347670672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347675424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347674192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347667680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316646155440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119133776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119126912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119129552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119135536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119212704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119216928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119213760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119219392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119218688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316347993952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119305552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119305200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140317925113552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119303616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119305024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119125328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119304144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316348005216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119313648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119314880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119310832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119313472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119126208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119437504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119441728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119434160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119447360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119446304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119448768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119435920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119447536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119438032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119552544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119552192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119549728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119552368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119559936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119558880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119561344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119557472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119560112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119547968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119651200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119655424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119652256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119661056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119660000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119656480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119649616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119661232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119651728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119734880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119735936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119732064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119734704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119742272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119741216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119743680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119739808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119742448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119730304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119849920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119854144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119850976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119856608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119893088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119855376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119857664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119892032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119850448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119900832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119901888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119898016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119900656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119906992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119901184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316119855552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140316118190560: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
def plot_loss_acc(history):
    '''Plots the training and validation loss and accuracy from a history object'''
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    plt.plot(history.history["accuracy"])
    plt.plot(history.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train"], loc="upper left")
    plt.show()

    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.title("model loss")
    plt.ylabel("loss")
    plt.xlabel("epoch")
    plt.legend(["train"], loc="upper left")
    plt.show()

    plt.show()

plot_loss_acc(history)

# %%
results = model.evaluate(test_dataset, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 0.82031
# Test Accuracy: 95.00%

# %%
train_df, test_df = train_test_split(image_df, test_size=0.2, shuffle=True, random_state=1)

# %%
checkpoint_model = tf.keras.models.load_model(os.path.join(MODEL_PATH, 'spoof_mobilenetv3s_finetuned_checkpoint_ariel8.keras'))

# %%
checkpoint_results = checkpoint_model.evaluate(test_dataset, verbose=0)

print("    Test Loss: {:.5f}".format(checkpoint_results[0]))
print("Test Accuracy: {:.2f}%".format(checkpoint_results[1] * 100))
# Out:
#     Test Loss: 0.82031
# Test Accuracy: 95.00%

# %%
# Predict the label of the test_images
pred = model.predict(test_dataset)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (test_class_names)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 5 predictions: {pred[:5]}')
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 14s 855ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-b2eac2abc82c> in <cell line: 7>()
#       5 # Map the label
#       6 labels = (test_class_names)
# ----> 7 labels = dict((v,k) for k,v in labels.items())
#       8 pred = [labels[k] for k in pred]
#       9
#
# AttributeError: 'list' object has no attribute 'items'

# %%
# Display 15 random pictures from the dataset with their labels
random_index = np.random.randint(0, len(test_df) - 1, 15)
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(25, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_df.Filepath.iloc[random_index[i]]))
    if test_df.Label.iloc[random_index[i]] == pred[random_index[i]]:
      color = "green"
    else:
      color = "red"
    ax.set_title(f"True: {test_df.Label.iloc[random_index[i]]}\nPredicted: {pred[random_index[i]]}", color=color)
plt.show()
plt.tight_layout()

# %%
y_test = list(test_df.Label)
print(classification_report(y_test, pred))

# %%
report = classification_report(y_test, pred, output_dict=True)
df = pd.DataFrame(report).transpose()
df

# %%
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(5, 5), text_size=10, norm=False, savefig=False):
  """Makes a labelled confusion matrix comparing predictions and ground truth labels.

  If classes is passed, confusion matrix will be labelled, if not, integer class values
  will be used.

  Args:
    y_true: Array of truth labels (must be same shape as y_pred).
    y_pred: Array of predicted labels (must be same shape as y_true).
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    figsize: Size of output figure (default=(10, 10)).
    text_size: Size of output figure text (default=15).
    norm: normalize values or not (default=False).
    savefig: save confusion matrix to file (default=False).

  Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.

  Example usage:
    make_confusion_matrix(y_true=test_labels, # ground truth test labels
                          y_pred=y_preds, # predicted labels
                          classes=class_names, # array of class label names
                          figsize=(15, 15),
                          text_size=10)
  """
  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with

  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  # Are there a list of classes?
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])

  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes),
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels)

  # Make x-axis labels appear on bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()
  ### Added: Rotate xticks for readability & increase font size (required due to such a large confusion matrix)
  plt.xticks(rotation=90, fontsize=text_size)
  plt.yticks(fontsize=text_size)

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    if norm:
      plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)
    else:
      plt.text(j, i, f"{cm[i, j]}",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)

  # Save the figure to the current working directory
  if savefig:
    fig.savefig("confusion_matrix.png")

# %%
make_confusion_matrix(y_test, pred, list(labels.values()))

# %%
"""
from google.colab import files
files.download('/content/allpos_mobilenetv3l_checkpoint_ariel4.keras')
"""

# %%
# Quantize Save model
#model.save(os.path.join(MODEL_PATH, "allpos_mobilenetv3l_finetuned_ariel8.keras"))

# Mengonversi model ke TFLite
loaded_model = tf.keras.models.load_model(os.path.join(MODEL_PATH, 'spoof_mobilenetv3s_finetuned_checkpoint_ariel8.keras'))
converter = tf.lite.TFLiteConverter.from_keras_model(loaded_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float16]

tflite_fp16_model = converter.convert()

# Menyimpan model TFLite ke file
tflite_model_path = os.path.join(MODEL_PATH, 'spoof_mobilenetv3s_finetuned_fp16quantize_ariel8.tflite')
with open(tflite_model_path, 'wb') as f:
    f.write(tflite_fp16_model)
# Out:
# Saved artifact at '/tmp/tmplqet5sid'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   140315838800544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838827504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838829616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838806352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838825216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838836304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838836480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838837008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838838064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838838768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838943072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838939200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838944480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838947824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838953456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838954336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838954688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838955216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838989056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838991344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838991520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838995920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838992576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838995216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838999792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838999968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315839004368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315839001024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315839003664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315839001200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315839105504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315839109904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315839106560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315839109200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315839112016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837090800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837089744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315839117824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837088688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837093968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837094144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837098544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837095200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837097840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837101888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837102768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837101712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837103824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837187344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837190336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837190512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837194912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837191568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837194208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315839109728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838802656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838805648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838806176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838826976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838829792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837201600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837201776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837302208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837308544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837308720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837313120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837309776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837312416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837315232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837316112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837315760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837316816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837366688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837370912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837371088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837375488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837372144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837374784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837380416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837381120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837381296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837481904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837487536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837487712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837492112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837488768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837491408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837495808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837496688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837494752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837497040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837547088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837551488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837551664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837556064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837552720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837555360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837560992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837561696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837561872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837662480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837668112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837668288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837672688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837669344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837671984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837676208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837677088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837727488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837675328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837727312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837731888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837732064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837736464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837733120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837735760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837741392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837742096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837742272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837842880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837848512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837848688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837853088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837849744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837852384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837855200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837856080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837855024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837857312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837855728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837927264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837927440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837931840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837928496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837931136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837935888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837936944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315837928672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838021872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838027504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838027680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838032080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838028736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838031376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838035600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838036480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838035424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838037712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838034720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838109072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838109248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838113648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838110304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838112944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838118576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838119280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315838119456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836106528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836112160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836112336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836116736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836113392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836116032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836118848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836119728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836118672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836120784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836204304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836207296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836207472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836211872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836208528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836211168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836216800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836217504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836217680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836334672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836340304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836340480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836344880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836341536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836344176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836348400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836349280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836349632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836350160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836416768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836420464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836420640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836425040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836421696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836424336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836429968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836430672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836430848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836498688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836504320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836504496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836508896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836505552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836508192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836512416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836513296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836512944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836514000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836596640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836601392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836610896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836611776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140315836992672: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
interpreter = tf.lite.Interpreter(model_path=str(os.path.join(MODEL_PATH, 'Model_ariel_planB/spoof_mobilenetv2_fp16_planB_ariel1.tflite')))
interpreter.allocate_tensors()

# %%
def evaluate_model(interpreter, dataset):
  input_index = interpreter.get_input_details()[0]["index"]
  output_index = interpreter.get_output_details()[0]["index"]

  # Initialize lists to store predictions and ground truth labels
  prediction_digits = []
  test_labels = []

  # Iterate over the test dataset
  for image_batch, labels_batch in dataset:
    # Iterate over each image and label in the batch
    for test_image, label in zip(image_batch.numpy(), labels_batch.numpy()):
      # Pre-processing: add batch dimension and convert to float32
      test_image = np.expand_dims(test_image, axis=0).astype(np.float32)
      interpreter.set_tensor(input_index, test_image)

      # Run inference
      interpreter.invoke()

      # Post-processing: remove batch dimension and find the digit with highest probability
      output = interpreter.tensor(output_index)
      digit = np.argmax(output()[0])
      prediction_digits.append(digit)
      test_labels.append(np.argmax(label)) # Store the true label

  # Compare prediction results with ground truth labels to calculate accuracy
  accurate_count = 0
  for index in range(len(prediction_digits)):
    if prediction_digits[index] == test_labels[index]:
      accurate_count += 1
  accuracy = accurate_count * 1.0 / len(prediction_digits)

  return accuracy

# %%
print(evaluate_model(interpreter, test_dataset))
# Out:
# 1.0

# %% [markdown]
# ## TFLite metadata

# %%
# !pip uninstall tensorflow
# !pip install tensorflow=="2.13.0"
# Out:
# Found existing installation: tensorflow 2.17.1
# Uninstalling tensorflow-2.17.1:
#   Would remove:
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.10/dist-packages/tensorflow-2.17.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/tensorflow/*
# Proceed (Y/n)? y
#   Successfully uninstalled tensorflow-2.17.1
# Collecting tensorflow==2.13.0
#   Downloading tensorflow-2.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (24.3.25)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow==2.13.0)
#   Downloading gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (1.68.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (3.12.1)
# Collecting keras<2.14,>=2.13.1 (from tensorflow==2.13.0)
#   Downloading keras-2.13.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (18.1.1)
# Collecting numpy<=1.24.3,>=1.22 (from tensorflow==2.13.0)
#   Downloading numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (1.16.0)
# Collecting tensorboard<2.14,>=2.13 (from tensorflow==2.13.0)
#   Downloading tensorboard-2.13.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow==2.13.0)
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (2.5.0)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow==2.13.0)
#   Downloading typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (1.17.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.13.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2.27.0)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.14,>=2.13->tensorflow==2.13.0)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.2.2)
# Downloading tensorflow-2.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (524.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 MB 3.3 MB/s eta 0:00:00
# Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 42.6 MB/s eta 0:00:00
# Downloading numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 61.4 MB/s eta 0:00:00
# Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 68.7 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 22.9 MB/s eta 0:00:00
# Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: typing-extensions, tensorflow-estimator, numpy, keras, gast, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: keras
#     Found existing installation: keras 3.5.0
#     Uninstalling keras-3.5.0:
#       Successfully uninstalled keras-3.5.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.6.0
#     Uninstalling gast-0.6.0:
#       Successfully uninstalled gast-0.6.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.1
#     Uninstalling google-auth-oauthlib-1.2.1:
#       Successfully uninstalled google-auth-oauthlib-1.2.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.1
#     Uninstalling tensorboard-2.17.1:
#       Successfully uninstalled tensorboard-2.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sqlalchemy 2.0.36 requires typing-extensions>=4.6.0, but you have typing-extensions 4.5.0 which is incompatible.
# albucore 0.0.19 requires numpy>=1.24.4, but you have numpy 1.24.3 which is incompatible.
# albumentations 1.4.20 requires numpy>=1.24.4, but you have numpy 1.24.3 which is incompatible.
# langchain-core 0.3.21 requires typing-extensions>=4.7, but you have typing-extensions 4.5.0 which is incompatible.
# nibabel 5.3.2 requires typing-extensions>=4.6; python_version < "3.13", but you have typing-extensions 4.5.0 which is incompatible.
# openai 1.54.5 requires typing-extensions<5,>=4.11, but you have typing-extensions 4.5.0 which is incompatible.
# pydantic 2.10.3 requires typing-extensions>=4.12.2, but you have typing-extensions 4.5.0 which is incompatible.
# pydantic-core 2.27.1 requires typing-extensions!=4.7.0,>=4.6.0, but you have typing-extensions 4.5.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.13.0 which is incompatible.
# torch 2.5.1+cu121 requires typing-extensions>=4.8.0, but you have typing-extensions 4.5.0 which is incompatible.
# typeguard 4.4.1 requires typing-extensions>=4.10.0, but you have typing-extensions 4.5.0 which is incompatible.
# Successfully installed gast-0.4.0 google-auth-oauthlib-1.0.0 keras-2.13.1 numpy-1.24.3 tensorboard-2.13.0 tensorflow-2.13.0 tensorflow-estimator-2.13.0 typing-extensions-4.5.0

# %%
# !pip install tflite-support-nightly
# Out:
# Requirement already satisfied: tflite-support-nightly in /usr/local/lib/python3.10/dist-packages (0.4.4.dev20230716)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tflite-support-nightly) (1.4.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from tflite-support-nightly) (1.24.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tflite-support-nightly) (24.3.25)
# Requirement already satisfied: protobuf<4,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from tflite-support-nightly) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from tflite-support-nightly) (0.5.1)
# Requirement already satisfied: pybind11>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from tflite-support-nightly) (2.13.6)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->tflite-support-nightly) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->tflite-support-nightly) (2.22)

# %%
from tflite_support import flatbuffers
from tflite_support import metadata as _metadata
from tflite_support import metadata_schema_py_generated as _metadata_fb
from tflite_support.metadata_writers import image_classifier
from tflite_support.metadata_writers import metadata_info
from tflite_support.metadata_writers import writer_utils
from tflite_support import metadata_schema_py_generated as _metadata_fb

# %%
_MODEL_PATH = os.path.join(MODEL_PATH, "spoof_mobilenetv3s_finetuned_fp16quantize_255metadata_ariel8.tflite")
_LABEL_FILE = os.path.join(MODEL_PATH, "spoof_labels.txt")
_SAVE_TO_PATH = os.path.join(MODEL_PATH, "spoof_mobilenetv3s_finetuned_fp16quantize_255metadata_ariel8.tflite")

# %% [markdown]
# ### Metadata writer codegen

# %%
ImageClassifierWriter = image_classifier.MetadataWriter
_INPUT_NORM_MEAN = 127.5
_INPUT_NORM_STD = 127.5

# Create the metadata writer.
writer = ImageClassifierWriter.create_for_inference(
    writer_utils.load_file(_MODEL_PATH), [_INPUT_NORM_MEAN], [_INPUT_NORM_STD],
    [_LABEL_FILE])

# Verify the metadata generated by metadata writer.
print(writer.get_metadata_json())

# Populate the metadata into the model.
writer_utils.save_file(writer.populate(), _SAVE_TO_PATH)
# Out:
# {
#   "name": "ImageClassifier",
#   "description": "Identify the most prominent object in the image from a known set of categories.",
#   "subgraph_metadata": [
#     {
#       "input_tensor_metadata": [
#         {
#           "name": "image",
#           "description": "Input image to be classified.",
#           "content": {
#             "content_properties_type": "ImageProperties",
#             "content_properties": {
#               "color_space": "RGB"
#             }
#           },
#           "process_units": [
#             {
#               "options_type": "NormalizationOptions",
#               "options": {
#                 "mean": [
#                   127.5
#                 ],
#                 "std": [
#                   127.5
#                 ]
#               }
#             }
#           ],
#           "stats": {
#             "max": [
#               1.0
#             ],
#             "min": [
#               -1.0
#             ]
#           }
#         }
#       ],
#       "output_tensor_metadata": [
#         {
#           "name": "probability",
#           "description": "Probabilities of the labels respectively.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             }
#           },
#           "stats": {
#             "max": [
#               1.0
#             ],
#             "min": [
#               0.0
#             ]
#           },
#           "associated_files": [
#             {
#               "name": "spoof_labels.txt",
#               "description": "Labels for categories that the model can recognize.",
#               "type": "TENSOR_AXIS_LABELS"
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ### Metadata flatbuffer

# %%
# Creates model info.
model_meta = _metadata_fb.ModelMetadataT()
model_meta.name = "MobileNetV3 image classifier"
model_meta.description = ("Identify the most prominent face direction in the "
                          "image from a set of 2, real or fake.")
model_meta.version = "v8"
model_meta.author = "Ariel"
model_meta.license = ("Apache License. Version 2.0 "
                      "http://www.apache.org/licenses/LICENSE-2.0.")

# %%
# Creates input info.
input_meta = _metadata_fb.TensorMetadataT()

# Creates output info.
output_meta = _metadata_fb.TensorMetadataT()

# %%
input_meta.name = "image"
input_meta.description = (
    "Input image to be classified. The expected image is {0} x {1}, with "
    "three channels (red, blue, and green) per pixel. Each value in the "
    "tensor is a single byte between 0 and 255.".format(224, 224))
input_meta.content = _metadata_fb.ContentT()
input_meta.content.contentProperties = _metadata_fb.ImagePropertiesT()
input_meta.content.contentProperties.colorSpace = (
    _metadata_fb.ColorSpaceType.RGB)
input_meta.content.contentPropertiesType = (
    _metadata_fb.ContentProperties.ImageProperties)
input_normalization = _metadata_fb.ProcessUnitT()
input_normalization.optionsType = (
    _metadata_fb.ProcessUnitOptions.NormalizationOptions)
input_normalization.options = _metadata_fb.NormalizationOptionsT()
input_normalization.options.mean = [127.5]
input_normalization.options.std = [127.5]
input_meta.processUnits = [input_normalization]
input_stats = _metadata_fb.StatsT()
input_stats.max = [255]
input_stats.min = [0]
input_meta.stats = input_stats

# %%
# Creates output info.
output_meta = _metadata_fb.TensorMetadataT()
output_meta.name = "probability"
output_meta.description = "Probabilities of the 2 labels respectively."
output_meta.content = _metadata_fb.ContentT()
output_meta.content.content_properties = _metadata_fb.FeaturePropertiesT()
output_meta.content.contentPropertiesType = (
    _metadata_fb.ContentProperties.FeatureProperties)
output_stats = _metadata_fb.StatsT()
output_stats.max = [1.0]
output_stats.min = [0.0]
output_meta.stats = output_stats
label_file = _metadata_fb.AssociatedFileT()
label_file.name = os.path.basename(_LABEL_FILE)
label_file.description = "Labels for spoof directions that the model can recognize."
label_file.type = _metadata_fb.AssociatedFileType.TENSOR_AXIS_LABELS
output_meta.associatedFiles = [label_file]

# %%
# Creates subgraph info.
subgraph = _metadata_fb.SubGraphMetadataT()
subgraph.inputTensorMetadata = [input_meta]
subgraph.outputTensorMetadata = [output_meta]
model_meta.subgraphMetadata = [subgraph]

b = flatbuffers.Builder(0)
b.Finish(
    model_meta.Pack(b),
    _metadata.MetadataPopulator.METADATA_FILE_IDENTIFIER)
metadata_buf = b.Output()

# %%
populator = _metadata.MetadataPopulator.with_model_file(_MODEL_PATH)
populator.load_metadata_buffer(metadata_buf)
populator.load_associated_files([_LABEL_FILE])
populator.populate()

# %%
from tflite_support.metadata_writers import image_classifier
from tflite_support.metadata_writers import writer_utils

# %%
ImageClassifierWriter = image_classifier.MetadataWriter
# Normalization parameters is required when reprocessing the image. It is
# optional if the image pixel values are in range of [0, 255] and the input
# tensor is quantized to uint8. See the introduction for normalization and
# quantization parameters below for more details.
# https://www.tensorflow.org/lite/models/convert/metadata#normalization_and_quantization_parameters)
_INPUT_NORM_MEAN = 127.5
_INPUT_NORM_STD = 127.5

# Create the metadata writer.
writer = ImageClassifierWriter.create_for_inference(
    writer_utils.load_file(_MODEL_PATH), [_INPUT_NORM_MEAN], [_INPUT_NORM_STD],
    [_LABEL_FILE])

# Verify the metadata generated by metadata writer.
print(writer.get_metadata_json())

# Populate the metadata into the model.
writer_utils.save_file(writer.populate(), _SAVE_TO_PATH)
# Out:
# {
#   "name": "ImageClassifier",
#   "description": "Identify the most prominent object in the image from a known set of categories.",
#   "subgraph_metadata": [
#     {
#       "input_tensor_metadata": [
#         {
#           "name": "image",
#           "description": "Input image to be classified.",
#           "content": {
#             "content_properties_type": "ImageProperties",
#             "content_properties": {
#               "color_space": "RGB"
#             }
#           },
#           "process_units": [
#             {
#               "options_type": "NormalizationOptions",
#               "options": {
#                 "mean": [
#                   127.5
#                 ],
#                 "std": [
#                   127.5
#                 ]
#               }
#             }
#           ],
#           "stats": {
#             "max": [
#               1.0
#             ],
#             "min": [
#               -1.0
#             ]
#           }
#         }
#       ],
#       "output_tensor_metadata": [
#         {
#           "name": "probability",
#           "description": "Probabilities of the labels respectively.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             }
#           },
#           "stats": {
#             "max": [
#               1.0
#             ],
#             "min": [
#               0.0
#             ]
#           },
#           "associated_files": [
#             {
#               "name": "allpos_labels.txt",
#               "description": "Labels for categories that the model can recognize.",
#               "type": "TENSOR_AXIS_LABELS"
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }

# %%
model_buffer = writer_utils.load_file(_MODEL_PATH)

# Create general model information.
general_md = metadata_info.GeneralMd(
    name="ImageClassifier_FaceDirection",
    version="v4",
    description=("Identify the face Direction in the image from a "
                 "known set of categories."),
    author="Ariel",
    licenses="Apache License. Version 2.0")

# Create input tensor information.
input_md = metadata_info.InputImageTensorMd(
    name="input image",
    description=("Input image to be classified. The expected image is "
                 "224 x 224, with three channels (red, blue, and green) per "
                 "pixel. Each element in the tensor is a value between min and "
                 "max, where (per-channel) min is [-1] and max is [1]."),
    norm_mean=[127.5],
    norm_std=[127.5],
    color_space_type=_metadata_fb.ColorSpaceType.RGB,
    tensor_type=writer_utils.get_input_tensor_types(model_buffer)[0])

# Create output tensor information.
output_md = metadata_info.ClassificationTensorMd(
    name="probability",
    description="Probabilities of the 5 labels respectively.",
    label_files=[
        metadata_info.LabelFileMd(file_path=_LABEL_FILE,
                                  locale="en")
    ],
    tensor_type=writer_utils.get_output_tensor_types(model_buffer)[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-39c2cf22cfb5> in <cell line: 4>()
#       2
#       3 # Create general model information.
# ----> 4 general_md = metadata_info.GeneralMd(
#       5     name="ImageClassifier_FaceDirection",
#       6     version="v4",
#
# NameError: name 'metadata_info' is not defined

# %%
ImageClassifierWriter = image_classifier.MetadataWriter
# Create the metadata writer.
writer = ImageClassifierWriter.create_from_metadata_info(
    model_buffer, general_md, input_md, output_md)

# Verify the metadata generated by metadata writer.
print(writer.get_metadata_json())

# Populate the metadata into the model.
writer_utils.save_file(writer.populate(), _SAVE_TO_PATH)
# Out:
# {
#   "name": "ImageClassifier_FaceDirection",
#   "description": "Identify the face Direction in the image from a known set of categories.",
#   "version": "v4",
#   "subgraph_metadata": [
#     {
#       "input_tensor_metadata": [
#         {
#           "name": "input image",
#           "description": "Input image to be classified. The expected image is 224 x 224, with three channels (red, blue, and green) per pixel. Each element in the tensor is a value between min and max, where (per-channel) min is [-1] and max is [1].",
#           "content": {
#             "content_properties_type": "ImageProperties",
#             "content_properties": {
#               "color_space": "RGB"
#             }
#           },
#           "process_units": [
#             {
#               "options_type": "NormalizationOptions",
#               "options": {
#                 "mean": [
#                   127.5
#                 ],
#                 "std": [
#                   127.5
#                 ]
#               }
#             }
#           ],
#           "stats": {
#             "max": [
#               1.0
#             ],
#             "min": [
#               -1.0
#             ]
#           }
#         }
#       ],
#       "output_tensor_metadata": [
#         {
#           "name": "probability",
#           "description": "Probabilities of the 5 labels respectively.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             }
#           },
#           "stats": {
#             "max": [
#               1.0
#             ],
#             "min": [
#               0.0
#             ]
#           },
#           "associated_files": [
#             {
#               "name": "allpos_labels.txt",
#               "description": "Labels for categories that the model can recognize.",
#               "type": "TENSOR_AXIS_LABELS",
#               "locale": "en"
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "author": "Ariel",
#   "license": "Apache License. Version 2.0"
# }
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-52c079b9fc5f> in <cell line: 10>()
#       8
#       9 # Populate the metadata into the model.
# ---> 10 writer_utils.save_file(writer.populate(), _SAVE_TO_PATH)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_lite_support/metadata/python/metadata_writers/metadata_writer.py in populate(self)
#     177     if self._associated_files:
#     178       populator.load_associated_files(self._associated_files)
# --> 179     populator.populate()
#     180     self._populated_model_buffer = populator.get_model_buffer()
#     181     return self._populated_model_buffer
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_lite_support/metadata/python/metadata.py in populate(self)
#     361   def populate(self):
#     362     """Populates loaded metadata and associated files into the model file."""
# --> 363     self._assert_validate()
#     364     self._populate_metadata_buffer()
#     365     self._populate_associated_files()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_lite_support/metadata/python/metadata.py in _assert_validate(self)
#     390     for f in to_be_populated_files:
#     391       if f in packed_files:
# --> 392         raise ValueError("File, '{0}', has already been packed.".format(f))
#     393
#     394       if f not in recorded_files:
#
# ValueError: File, 'allpos_labels.txt', has already been packed.

# %%
Interpreter = Interpreter(model_path='/content/drive/MyDrive/Model_ariel/alpos_mobilenetv3s_ariel5.tflite')

# %%
loaded_model = tf.keras.models.load_model('/content/drive/MyDrive/Model_ariel/allpos_mobilenetv3s_checkpoint_ariel5.keras')
loaded_model.evaluate(test_dataset)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 22s 955ms/step - accuracy: 0.9909 - loss: 0.1122 - precision: 0.9909 - recall: 0.9909
# [0.1343877911567688,
#  0.9900000095367432,
#  0.9900000095367432,
#  0.9900000095367432]

# %% [markdown]
# ## Benchmark

# %%
# !adb install -r -d -g android_aarch64_benchmark_model.apk
# Out:
# /bin/bash: line 1: adb: command not found

# %%
# !adb push your_model.tflite /data/local/tmp
